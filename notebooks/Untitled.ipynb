# %%
# !conda search pandas
# Out:
# Loading channels: done
# # Name                  Version           Build  Channel
# pandas                    0.8.1      np16py26_0  pkgs/free
# pandas                    0.8.1      np16py27_0  pkgs/free
# pandas                    0.8.1      np17py26_0  pkgs/free
# pandas                    0.8.1      np17py27_0  pkgs/free
# pandas                    0.9.0      np16py26_0  pkgs/free
# pandas                    0.9.0      np16py27_0  pkgs/free
# pandas                    0.9.0      np17py26_0  pkgs/free
# pandas                    0.9.0      np17py27_0  pkgs/free
# pandas                    0.9.1      np16py26_0  pkgs/free
# pandas                    0.9.1      np16py27_0  pkgs/free
# pandas                    0.9.1      np17py26_0  pkgs/free
# pandas                    0.9.1      np17py27_0  pkgs/free
# pandas                   0.10.0      np16py26_0  pkgs/free
# pandas                   0.10.0      np16py27_0  pkgs/free
# pandas                   0.10.0      np17py26_0  pkgs/free
# pandas                   0.10.0      np17py27_0  pkgs/free
# pandas                   0.10.1      np16py26_0  pkgs/free
# pandas                   0.10.1      np16py27_0  pkgs/free
# pandas                   0.10.1      np17py26_0  pkgs/free
# pandas                   0.10.1      np17py27_0  pkgs/free
# pandas                   0.10.1      np17py33_0  pkgs/free
# pandas                   0.11.0      np16py26_1  pkgs/free
# pandas                   0.11.0      np16py27_1  pkgs/free
# pandas                   0.11.0      np17py26_1  pkgs/free
# pandas                   0.11.0      np17py27_1  pkgs/free
# pandas                   0.11.0      np17py33_1  pkgs/free
# pandas                   0.12.0      np16py26_0  pkgs/free
# pandas                   0.12.0      np16py27_0  pkgs/free
# pandas                   0.12.0      np17py26_0  pkgs/free
# pandas                   0.12.0      np17py27_0  pkgs/free
# pandas                   0.12.0      np17py33_0  pkgs/free
# pandas                   0.13.0      np17py26_0  pkgs/free
# pandas                   0.13.0      np17py27_0  pkgs/free
# pandas                   0.13.0      np17py33_0  pkgs/free
# pandas                   0.13.0      np18py26_0  pkgs/free
# pandas                   0.13.0      np18py27_0  pkgs/free
# pandas                   0.13.0      np18py33_0  pkgs/free
# pandas                   0.13.1      np18py26_0  pkgs/free
# pandas                   0.13.1      np18py27_0  pkgs/free
# pandas                   0.13.1      np18py33_0  pkgs/free
# pandas                   0.13.1      np18py34_0  pkgs/free
# pandas                   0.14.0      np18py26_0  pkgs/free
# pandas                   0.14.0      np18py27_0  pkgs/free
# pandas                   0.14.0      np18py33_0  pkgs/free
# pandas                   0.14.0      np18py34_0  pkgs/free
# pandas                   0.14.1     np110py27_0  pkgs/free
# pandas                   0.14.1     np110py34_0  pkgs/free
# pandas                   0.14.1      np18py26_0  pkgs/free
# pandas                   0.14.1      np18py27_0  pkgs/free
# pandas                   0.14.1      np18py33_0  pkgs/free
# pandas                   0.14.1      np18py34_0  pkgs/free
# pandas                   0.14.1      np19py26_0  pkgs/free
# pandas                   0.14.1      np19py27_0  pkgs/free
# pandas                   0.14.1      np19py33_0  pkgs/free
# pandas                   0.14.1      np19py34_0  pkgs/free
# pandas                   0.15.0      np19py26_0  pkgs/free
# pandas                   0.15.0      np19py27_0  pkgs/free
# pandas                   0.15.0      np19py33_0  pkgs/free
# pandas                   0.15.0      np19py34_0  pkgs/free
# pandas                   0.15.1      np19py26_0  pkgs/free
# pandas                   0.15.1      np19py27_0  pkgs/free
# pandas                   0.15.1      np19py33_0  pkgs/free
# pandas                   0.15.1      np19py34_0  pkgs/free
# pandas                   0.15.2      np19py26_0  pkgs/free
# pandas                   0.15.2      np19py26_1  pkgs/free
# pandas                   0.15.2      np19py27_0  pkgs/free
# pandas                   0.15.2      np19py27_1  pkgs/free
# pandas                   0.15.2      np19py33_0  pkgs/free
# pandas                   0.15.2      np19py33_1  pkgs/free
# pandas                   0.15.2      np19py34_0  pkgs/free
# pandas                   0.15.2      np19py34_1  pkgs/free
# pandas                   0.16.0      np19py26_1  pkgs/free
# pandas                   0.16.0      np19py27_1  pkgs/free
# pandas                   0.16.0      np19py33_1  pkgs/free
# pandas                   0.16.0      np19py34_1  pkgs/free
# pandas                   0.16.1      np19py26_0  pkgs/free
# pandas                   0.16.1      np19py27_0  pkgs/free
# pandas                   0.16.1      np19py33_0  pkgs/free
# pandas                   0.16.1      np19py34_0  pkgs/free
# pandas                   0.16.2     np110py27_0  pkgs/free
# pandas                   0.16.2     np110py34_0  pkgs/free
# pandas                   0.16.2     np110py35_0  pkgs/free
# pandas                   0.16.2      np19py26_0  pkgs/free
# pandas                   0.16.2      np19py27_0  pkgs/free
# pandas                   0.16.2      np19py33_0  pkgs/free
# pandas                   0.16.2      np19py34_0  pkgs/free
# pandas                   0.16.2      np19py35_0  pkgs/free
# pandas                   0.17.0     np110py27_0  pkgs/free
# pandas                   0.17.0     np110py34_0  pkgs/free
# pandas                   0.17.0     np110py35_0  pkgs/free
# pandas                   0.17.1     np110py27_0  pkgs/free
# pandas                   0.17.1     np110py34_0  pkgs/free
# pandas                   0.17.1     np110py35_0  pkgs/free
# pandas                   0.18.0     np110py27_0  pkgs/free
# pandas                   0.18.0     np110py34_0  pkgs/free
# pandas                   0.18.0     np110py35_0  pkgs/free
# pandas                   0.18.0     np111py27_0  pkgs/free
# pandas                   0.18.0     np111py34_0  pkgs/free
# pandas                   0.18.0     np111py35_0  pkgs/free
# pandas                   0.18.1     np110py27_0  pkgs/free
# pandas                   0.18.1     np110py34_0  pkgs/free
# pandas                   0.18.1     np110py35_0  pkgs/free
# pandas                   0.18.1     np111py27_0  pkgs/free
# pandas                   0.18.1     np111py34_0  pkgs/free
# pandas                   0.18.1     np111py35_0  pkgs/free
# pandas                   0.19.0     np111py27_0  pkgs/free
# pandas                   0.19.0     np111py34_0  pkgs/free
# pandas                   0.19.0     np111py35_0  pkgs/free
# pandas                   0.19.1     np111py27_0  pkgs/free
# pandas                   0.19.1     np111py34_0  pkgs/free
# pandas                   0.19.1     np111py35_0  pkgs/free
# pandas                   0.19.1     np111py36_0  pkgs/free
# pandas                   0.19.2     np111py27_0  pkgs/free
# pandas                   0.19.2     np111py27_1  pkgs/free
# pandas                   0.19.2     np111py34_0  pkgs/free
# pandas                   0.19.2     np111py34_1  pkgs/free
# pandas                   0.19.2     np111py35_0  pkgs/free
# pandas                   0.19.2     np111py35_1  pkgs/free
# pandas                   0.19.2     np111py36_0  pkgs/free
# pandas                   0.19.2     np111py36_1  pkgs/free
# pandas                   0.19.2     np112py27_1  pkgs/free
# pandas                   0.19.2     np112py35_1  pkgs/free
# pandas                   0.19.2     np112py36_1  pkgs/free
# pandas                   0.20.1     np111py27_0  pkgs/free
# pandas                   0.20.1     np111py35_0  pkgs/free
# pandas                   0.20.1     np111py36_0  pkgs/free
# pandas                   0.20.1     np112py27_0  pkgs/free
# pandas                   0.20.1     np112py35_0  pkgs/free
# pandas                   0.20.1     np112py36_0  pkgs/free
# pandas                   0.20.2     np112py27_0  pkgs/free
# pandas                   0.20.2     np112py35_0  pkgs/free
# pandas                   0.20.2     np112py36_0  pkgs/free
# pandas                   0.20.2     np113py27_0  pkgs/free
# pandas                   0.20.2     np113py35_0  pkgs/free
# pandas                   0.20.2     np113py36_0  pkgs/free
# pandas                   0.20.3          py27_0  pkgs/free
# pandas                   0.20.3  py27h2a3d8ca_2  pkgs/main
# pandas                   0.20.3          py35_0  pkgs/free
# pandas                   0.20.3  py35h5e2f206_2  pkgs/main
# pandas                   0.20.3          py36_0  pkgs/free
# pandas                   0.20.3  py36hd6655d8_2  pkgs/main
# pandas                   0.21.0  py27h860f240_1  pkgs/main
# pandas                   0.21.0  py27h8d379d7_0  pkgs/main
# pandas                   0.21.0  py35h4431f20_1  pkgs/main
# pandas                   0.21.0  py35h4af63c7_0  pkgs/main
# pandas                   0.21.0  py36hd8e0503_0  pkgs/main
# pandas                   0.21.0  py36hfed917e_1  pkgs/main
# pandas                   0.21.1  py27h1cb45b9_0  pkgs/main
# pandas                   0.21.1  py35h2c08c6b_0  pkgs/main
# pandas                   0.21.1  py36h2c08c6b_0  pkgs/main
# pandas                   0.22.0  py27h0a44026_0  pkgs/main
# pandas                   0.22.0  py35h0a44026_0  pkgs/main
# pandas                   0.22.0  py36h0a44026_0  pkgs/main
# pandas                   0.23.0  py27h1702cab_0  pkgs/main
# pandas                   0.23.0  py35h1702cab_0  pkgs/main
# pandas                   0.23.0  py36h1702cab_0  pkgs/main
# pandas                   0.23.1  py27h1702cab_0  pkgs/main
# pandas                   0.23.1  py35h1702cab_0  pkgs/main
# pandas                   0.23.1  py36h1702cab_0  pkgs/main
# pandas                   0.23.2  py27h6440ff4_0  pkgs/main
# pandas                   0.23.2  py36h6440ff4_0  pkgs/main
# pandas                   0.23.2  py37h6440ff4_0  pkgs/main
# pandas                   0.23.3  py27h6440ff4_0  pkgs/main
# pandas                   0.23.3  py35h6440ff4_0  pkgs/main
# pandas                   0.23.3  py36h6440ff4_0  pkgs/main
# pandas                   0.23.3  py37h6440ff4_0  pkgs/main
# pandas                   0.23.4  py27h6440ff4_0  pkgs/main
# pandas                   0.23.4  py35h6440ff4_0  pkgs/main
# pandas                   0.23.4  py36h6440ff4_0  pkgs/main
# pandas                   0.23.4  py37h6440ff4_0  pkgs/main
# pandas                   0.24.0  py27h0a44026_0  pkgs/main
# pandas                   0.24.0  py36h0a44026_0  pkgs/main
# pandas                   0.24.0  py37h0a44026_0  pkgs/main
# pandas                   0.24.1  py27h0a44026_0  pkgs/main
# pandas                   0.24.1  py36h0a44026_0  pkgs/main
# pandas                   0.24.1  py37h0a44026_0  pkgs/main
# pandas                   0.24.2  py27h0a44026_0  pkgs/main
# pandas                   0.24.2  py36h0a44026_0  pkgs/main
# pandas                   0.24.2  py37h0a44026_0  pkgs/main

# %%
# !conda search s3fs
# Out:
# Loading channels: done
# # Name                  Version           Build  Channel
# s3fs                      0.0.2          py27_0  pkgs/free
# s3fs                      0.0.2          py34_0  pkgs/free
# s3fs                      0.0.2          py35_0  pkgs/free
# s3fs                      0.0.4          py27_0  pkgs/free
# s3fs                      0.0.4          py34_0  pkgs/free
# s3fs                      0.0.4          py35_0  pkgs/free
# s3fs                      0.0.6          py27_0  pkgs/free
# s3fs                      0.0.6          py34_0  pkgs/free
# s3fs                      0.0.6          py35_0  pkgs/free
# s3fs                      0.0.7          py27_0  pkgs/free
# s3fs                      0.0.7          py34_0  pkgs/free
# s3fs                      0.0.7          py35_0  pkgs/free
# s3fs                      0.0.8          py27_0  pkgs/free
# s3fs                      0.0.8          py34_0  pkgs/free
# s3fs                      0.0.8          py35_0  pkgs/free
# s3fs                      0.0.8          py36_0  pkgs/free
# s3fs                      0.0.9          py27_0  pkgs/free
# s3fs                      0.0.9          py35_0  pkgs/free
# s3fs                      0.0.9          py36_0  pkgs/free
# s3fs                      0.1.0          py27_0  pkgs/free
# s3fs                      0.1.0          py35_0  pkgs/free
# s3fs                      0.1.0          py36_0  pkgs/free
# s3fs                      0.1.1          py27_0  pkgs/free
# s3fs                      0.1.1          py35_0  pkgs/free
# s3fs                      0.1.1          py36_0  pkgs/free
# s3fs                      0.1.2          py27_0  pkgs/free
# s3fs                      0.1.2          py35_0  pkgs/free
# s3fs                      0.1.2          py36_0  pkgs/free
# s3fs                      0.1.3          py27_0  pkgs/main
# s3fs                      0.1.3          py35_0  pkgs/main
# s3fs                      0.1.3          py36_0  pkgs/main
# s3fs                      0.1.4          py27_0  pkgs/main
# s3fs                      0.1.4          py35_0  pkgs/main
# s3fs                      0.1.4          py36_0  pkgs/main
# s3fs                      0.1.5          py27_0  pkgs/main
# s3fs                      0.1.5          py35_0  pkgs/main
# s3fs                      0.1.5          py36_0  pkgs/main
# s3fs                      0.1.5          py37_0  pkgs/main
# s3fs                      0.1.6          py27_0  pkgs/main
# s3fs                      0.1.6          py35_0  pkgs/main
# s3fs                      0.1.6          py36_0  pkgs/main
# s3fs                      0.1.6          py37_0  pkgs/main
# s3fs                      0.2.0          py27_0  pkgs/main
# s3fs                      0.2.0          py36_0  pkgs/main
# s3fs                      0.2.0          py37_0  pkgs/main

# %%
import pandas as pd

# %%
# from sagemaker import get_execution_role

# role = get_execution_role()
bucket = 'hacko-data-archieve'
data_key = '2018-neighborhood-development/JSON/pdx_bicycle/pdx_bike_counts.csv'

data_location = 's3://{}/{}'.format(bucket, data_key)
output_location = 's3://{}/{}'.format(bucket, data_key)

# %%
# !conda install -y s3fs

# %%
pd.read_csv(data_location)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~/miniconda3/py36_envs/ml_devenv/lib/python3.6/site-packages/pandas/io/s3.py in <module>
#       3 try:
# ----> 4     import s3fs
#       5     from botocore.exceptions import NoCredentialsError
#
# ModuleNotFoundError: No module named 's3fs'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# <ipython-input-3-7aa8867d8d6b> in <module>
# ----> 1 pd.read_csv(data_location)
#
# ~/miniconda3/py36_envs/ml_devenv/lib/python3.6/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, doublequote, delim_whitespace, low_memory, memory_map, float_precision)
#     676                     skip_blank_lines=skip_blank_lines)
#     677
# --> 678         return _read(filepath_or_buffer, kwds)
#     679
#     680     parser_f.__name__ = name
#
# ~/miniconda3/py36_envs/ml_devenv/lib/python3.6/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     422     compression = _infer_compression(filepath_or_buffer, compression)
#     423     filepath_or_buffer, _, compression, should_close = get_filepath_or_buffer(
# --> 424         filepath_or_buffer, encoding, compression)
#     425     kwds['compression'] = compression
#     426
#
# ~/miniconda3/py36_envs/ml_devenv/lib/python3.6/site-packages/pandas/io/common.py in get_filepath_or_buffer(filepath_or_buffer, encoding, compression, mode)
#     203
#     204     if is_s3_url(filepath_or_buffer):
# --> 205         from pandas.io import s3
#     206         return s3.get_filepath_or_buffer(filepath_or_buffer,
#     207                                          encoding=encoding,
#
# ~/miniconda3/py36_envs/ml_devenv/lib/python3.6/site-packages/pandas/io/s3.py in <module>
#       5     from botocore.exceptions import NoCredentialsError
#       6 except:
# ----> 7     raise ImportError("The s3fs library is required to handle s3 files")
#       8
#       9 if compat.PY3:
#
# ImportError: The s3fs library is required to handle s3 files
